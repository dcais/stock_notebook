# %%
import sys
from pyecharts import options as opts
sys.path.append("..") 
from imp import reload
from src.stock import Stock

# %%
stock = Stock()
# Out:
# /Users/david/anaconda3/lib/python3.6/site-packages/tushare/util/upass.py:28: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   return str(df.ix[0]['token'])

# %%
stock.get_hs_300()
# Out:
#           index_code   con_code trade_date  weight
# con_code
# 002773.SZ  399300.SZ  002773.SZ   20191008  0.0702
# 002714.SZ  399300.SZ  002714.SZ   20191008  0.5026
# 601238.SH  399300.SZ  601238.SH   20191008  0.0904
# 603288.SH  399300.SZ  603288.SH   20191008  0.7087
# 603993.SH  399300.SZ  603993.SH   20191008  0.2045
# ...              ...        ...        ...     ...
# 000333.SZ  399300.SZ  000333.SZ   20191008  2.0500
# 601808.SH  399300.SZ  601808.SH   20191008  0.0588
# 601939.SH  399300.SZ  601939.SH   20191008  0.3812
# 002179.SZ  399300.SZ  002179.SZ   20191008  0.1636
# 601169.SH  399300.SZ  601169.SH   20191008  0.6396
#
# [300 rows x 4 columns]

# %%
stock.get_zz_500()
# Out:
#           index_code   con_code trade_date  weight
# con_code
# 002390.SZ  000905.SH  002390.SZ   20190930   0.145
# 002387.SZ  000905.SH  002387.SZ   20190930   0.365
# 002385.SZ  000905.SH  002385.SZ   20190930   0.305
# 002384.SZ  000905.SH  002384.SZ   20190930   0.498
# 002382.SZ  000905.SH  002382.SZ   20190930   0.097
# ...              ...        ...        ...     ...
# 600729.SH  000905.SH  600729.SH   20190930   0.183
# 600718.SH  000905.SH  600718.SH   20190930   0.250
# 600717.SH  000905.SH  600717.SH   20190930   0.162
# 600707.SH  000905.SH  600707.SH   20190930   0.085
# 600699.SH  000905.SH  600699.SH   20190930   0.354
#
# [500 rows x 4 columns]

# %%
stock.get_sz_50()
# Out:
#           index_code   con_code trade_date  weight
# con_code
# 601668.SH  000016.SH  601668.SH   20190930   2.045
# 601186.SH  000016.SH  601186.SH   20190930   0.781
# 601211.SH  000016.SH  601211.SH   20190930   1.421
# 601229.SH  000016.SH  601229.SH   20190930   1.191
# 601288.SH  000016.SH  601288.SH   20190930   2.378
# 601318.SH  000016.SH  601318.SH   20190930  16.915
# 601319.SH  000016.SH  601319.SH   20190930   0.164
# 601328.SH  000016.SH  601328.SH   20190930   2.686
# 601336.SH  000016.SH  601336.SH   20190930   0.728
# 601390.SH  000016.SH  601390.SH   20190930   0.877
# 601398.SH  000016.SH  601398.SH   20190930   2.140
# 601601.SH  000016.SH  601601.SH   20190930   1.966
# 601628.SH  000016.SH  601628.SH   20190930   0.821
# 601166.SH  000016.SH  601166.SH   20190930   4.573
# 601688.SH  000016.SH  601688.SH   20190930   1.247
# 601766.SH  000016.SH  601766.SH   20190930   1.278
# 601800.SH  000016.SH  601800.SH   20190930   0.426
# ...
