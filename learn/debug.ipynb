# %%
def do_some_thing_about(b):
    return b

def fun2(a):
    import ipdb; ipdb.set_trace() # debugging starts here
    return do_some_thing_about(a)

def fun1(a):
   return fun2(a)

# %%
fun1(1)
# Out:
# > <ipython-input-10-0cff81801b3b>(6)fun2()
#       5     import ipdb; ipdb.set_trace() # debugging starts here
# ----> 6     return do_some_thing_about(a)
#       7
#
# ipdb> w
#   /Users/david/anaconda3/lib/python3.6/runpy.py(193)_run_module_as_main()
#     192     return _run_code(code, main_globals, None,
# --> 193                      "__main__", mod_spec)
#     194
#
#   /Users/david/anaconda3/lib/python3.6/runpy.py(85)_run_code()
#      84                        __spec__ = mod_spec)
# ---> 85     exec(code, run_globals)
#      86     return run_globals
#
#   /Users/david/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py(16)<module>()
#      14
#      15     from ipykernel import kernelapp as app
# ---> 16     app.launch_new_instance()
#
#   /Users/david/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py(658)launch_instance()
#     657         app.initialize(argv)
# --> 658         app.start()
#     659
#
# ...
